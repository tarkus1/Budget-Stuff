# %%
from tabula import read_pdf
df =read_pdf("/home/mark/Downloads/451401XXXXXX3663-2019May09-2019Jun10.pdf",pages="all")
df
# Out:
#                                                 MAY 06  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                               MAY 08
# 4                                                  NaN
# 5                                                  NaN
# 6                                               MAY 09
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                              MAY 09
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                              MAY 09
# 15                                                 NaN
# ...

# %%
df
# Out:
#     MAY 16  MAY 21            SHAW CABLESYSTEMS CALGARY AB     $169.05  \
# 0      NaN     NaN                                     NaN         NaN
# 1      NaN     NaN                 74529009136920300447608         NaN
# 2   MAY 16  MAY 17      OLLY FRESCO'S WATERMARK CALGARY AB       $9.43
# 3      NaN     NaN                 74064499136820236782793         NaN
# 4   MAY 17  MAY 21      MCDONALD'S #9071 MYMCDS CALGARY AB       $6.17
# 5      NaN     NaN                 74064499138820110765292         NaN
# 6   MAY 17  MAY 21              ATCO ENERGY LTD CALGARY AB     $238.76
# 7      NaN     NaN                                     NaN         NaN
# 8      NaN     NaN                 74064499138820111899223         NaN
# 9      NaN     NaN                                     NaN         NaN
# 10  MAY 17  MAY 17     TOWER CENTRE SPORT PHYSIOCALGARY AB     $120.75
# 11     NaN     NaN                                     NaN         NaN
# ...
